# %%
root = "/home/fanqiliang/data/picai"
import os
from glob import glob
import matplotlib.pyplot as plt
import SimpleITK as sitk

# %%
arr_file = "/home/fanqiliang/data/picai/96.mhd"
seg_file = "/home/fanqiliang/data/picai/96_seg.mhd"

arr = sitk.GetArrayFromImage(sitk.ReadImage(arr_file))
seg = sitk.GetArrayFromImage(sitk.ReadImage(seg_file))

# %%
plt.figure()
plt.imshow(arr[5])
plt.show()
plt.figure()
plt.imshow(seg[5])
plt.figure()
