# %%
import os
from glob import glob
import SimpleITK as sitk
import matplotlib.pyplot as plt

# %%
origin_root = "/home/fanqiliang/data/prostate158_origin/train"
sample = os.path.join(origin_root, "080", "t2_anatomy_reader1.nii.gz")

# %%
arr = sitk.GetArrayFromImage(sitk.ReadImage(sample))

plt.figure()
plt.imshow(arr[arr.shape[0]//2])
plt.show()
plt.close()

print(set(arr.flatten().tolist()))
# Out:
# {0, 1, 2}
